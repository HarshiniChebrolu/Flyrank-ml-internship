# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HarshiniChebrolu/Flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# #Freestyle
#
# Future Content Performance Prediction
# I chose this freestyle lane because I want to predict future content performance using historical page-level data. The goal is to help content editors identify pages that are likely to improve, decline, recover, or remain stable so that they can make proactive decisions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Research Question:
# Can historical page-level content, visibility, and engagement signals be used to predict future content performance?
#
# Decision:
# Which content pages should editors monitor, update, or prioritize based on their predicted future performance?
#
# Who Acts?
# Content editors and SEO specialists.
#
# Action:
# They can update pages that are predicted to decline, monitor pages showing uncertain performance, or continue supporting pages likely to grow.
#
# Cost of a Wrong Recommendation:
#
# False Positive:
# Editors spend time reviewing or updating pages that did not need attention.
#
# False Negative:
# A page that actually declines is missed, leading to lost traffic and missed opportunities for improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
#
#
# The starter dataset contains 30,000 content pages across 32 clients and includes 44 features describing historical content performance.
#
# The average CTR is 0.51%, the average engagement rate is 2.53%, and the average number of sessions is 37.07.
#
# These historical visibility and engagement signals provide useful information for studying whether they can help predict future content performance.

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

# Get the uploaded filename automatically
filename = next(iter(uploaded))

df = pd.read_csv(filename)

print(df.shape)
# Out:
#      <input type="file" id="files-2c2f5e06-cdb9-4b29-9930-938ccade35bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c2f5e06-cdb9-4b29-9930-938ccade35bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.shape)
print("Total Rows:", df.shape[0])
print("Total Columns:", df.shape[1])
print("Unique Clients:", df["client_id"].nunique())
print("Unique Content Types:", df["content_type"].nunique())

print("\nAverage CTR (%):", round(df["ctr"].mean(), 2))
print("Average Engagement Rate (%):", round(df["engagement_rate"].mean(), 2))
print("Average Sessions:", round(df["sessions_90d"].mean(), 2))
# Out:
# (30000, 44)
# Total Rows: 30000
# Total Columns: 44
# Unique Clients: 32
# Unique Content Types: 3
#
# Average CTR (%): 0.51
# Average Engagement Rate (%): 2.53
# Average Sessions: 37.07

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project aims to identify patterns in historical content performance and estimate future content performance to support editorial decisions.
#
# The results should be used as decision-support, not as guaranteed predictions.
#
# This project cannot prove that one factor causes better or worse performance, and it cannot predict or explain Google's ranking algorithm. The predictions are based only on patterns found in the available historical data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
